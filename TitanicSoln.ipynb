# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
traindata= pd.read_csv("C:/Users/dhans/Desktop/train.csv")
testdata= pd.read_csv("C:/Users/dhans/Desktop/test.csv")

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
traindata.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(traindata.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x=traindata['Age'].mean()
x
traindata['Age'].fillna(x, inplace=True)

# %%
x=testdata['Age'].mean()
x
testdata['Age'].fillna(x, inplace=True)

# %%
print(traindata[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#females survived more
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
print(traindata[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#pclass=1 survived more
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
print(traindata[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#ppl with sibsp 1 survived more
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
print(traindata[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#ppl with parch 3 survived more
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
sb.barplot(x="Sex", y="Survived", data=traindata)
plt.title("Survival based on Sex")
plt.show()
# Out:
# C:\Users\dhans\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.barplot(x="Pclass", y="Survived", data=traindata)
plt.title("Survival based on Pclass")
plt.show()
# Out:
# C:\Users\dhans\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
traindata["Embarked"].fillna('S', inplace=True)
testdata["Embarked"].fillna('S', inplace=True)
traindata['Place'] = traindata['Embarked'].map( {'S': 1, 'C': 2, 'Q': 3} ).astype(int)
testdata['Place'] = testdata['Embarked'].map({'S': 1, 'C': 2, 'Q': 3}).astype(int)

# %%
traindata.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
testdata.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Place
# ...

# %%
print(traindata.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Place            0
# dtype: int64

# %%
print(testdata.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Place            0
# dtype: int64

# %%
testdata["Fare"].fillna(testdata["Fare"].mean(), inplace=True)

# %%
print(testdata.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Place            0
# dtype: int64

# %%
traindata['Family']= traindata['SibSp']+traindata['Parch']
testdata['Family']= testdata['SibSp']+testdata['Parch']

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Place  Family
# 0      0         A/5 21171   7.2500   NaN        S      1       1
# 1      0          PC 17599  71.2833   C85        C      2       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1       0
# ...

# %%
traindata['Gender'] = traindata['Sex'].map( {'male': 2, 'female': 1} ).astype(int)
testdata['Gender'] = testdata['Sex'].map({'male': 2, 'female': 1}).astype(int)

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Place  Family  Gender
# 0      0         A/5 21171   7.2500   NaN        S      1       1       2
# 1      0          PC 17599  71.2833   C85        C      2       1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1       0       1
# ...

# %%
testdata.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Place  Family  Gender
# 0  34.5      0      0   330911   7.8292   NaN        Q      3       0       2
# 1  47.0      1      0   363272   7.0000   NaN        S      1       1       1
# 2  62.0      0      0   240276   9.6875   NaN        Q      3       0       2
# 3  27.0      0      0   315154   8.6625   NaN        S      1       0       2
# 4  22.0      1      1  3101298  12.2875   NaN        S      1       2       1

# %%
traindata.loc[traindata['Age']<=10, 'A']=1
traindata.loc[(traindata['Age']>10) & (traindata['Age']<=30), 'A']=2
traindata.loc[(traindata['Age']>30) & (traindata['Age']<=50), 'A']=3
traindata.loc[(traindata['Age']>50) & (traindata['Age']<=70), 'A']=4
traindata.loc[traindata['Age']>70, 'A']=5
traindata.drop(labels=['PassengerId', 'Ticket'], axis=1, inplace=True)
traindata.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex        Age  SibSp  Parch     Fare Cabin Embarked  Place  Family  \
# 0    male  22.000000      1      0   7.2500   NaN        S      1       1
# ...

# %%
print(traindata[["A", "Survived"]].groupby(['A'], as_index=False).mean().sort_values(by='Survived', ascending=False))
# Out:
#      A  Survived
# 0  1.0  0.593750
# 2  3.0  0.423237
# 3  4.0  0.355932
# 1  2.0  0.344828
# 4  5.0  0.200000

# %%
testdata.loc[testdata['Age']<=10, 'A']=1
testdata.loc[(testdata['Age']>10) & (testdata['Age']<=30), 'A']=2
testdata.loc[(testdata['Age']>30) & (testdata['Age']<=50), 'A']=3
testdata.loc[(testdata['Age']>50) & (testdata['Age']<=70), 'A']=4
testdata.loc[testdata['Age']>70, 'A']=5
testdata.drop(labels=['PassengerId', 'Ticket'], axis=1, inplace=True)
testdata.head(10)
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5       3                    Svensson, Mr. Johan Cervin    male  14.0      0
# 6       3                          Connolly, Miss. Kate  female  30.0      0
# 7       2                  Caldwell, Mr. Albert Francis    male  26.0      1
# 8       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9       3                       Davies, Mr. John Samuel    male  21.0      2
#
#    Parch     Fare Cabin Embarked  Place  Family  Gender    A
# 0      0   7.8292   NaN        Q      3       0       2  3.0
# ...

# %%
traindata.loc[traindata['Fare']<=10, 'F']=1
traindata.loc[(traindata['Fare']>10) & (traindata['Fare']<=30), 'F']=2
traindata.loc[(traindata['Fare']>30) & (traindata['Fare']<=50), 'F']=3
traindata.loc[(traindata['Fare']>50) & (traindata['Fare']<=70), 'F']=4
traindata.loc[(traindata['Fare']>70) & (traindata['Fare']<=100), 'F']=4
traindata.loc[traindata['Fare']>100, 'F']=5
traindata.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Place  Family  Gender  \
# 0    male  22.0      1      0   7.2500   NaN        S      1       1       2
# 1  female  38.0      1      0  71.2833   C85        C      2       1       1
# 2  female  26.0      0      0   7.9250   NaN        S      1       0       1
# 3  female  35.0      1      0  53.1000  C123        S      1       1       1
# 4    male  35.0      0      0   8.0500   NaN        S      1       0       2
#
#      A    F
# 0  2.0  1.0
# 1  3.0  4.0
# 2  2.0  1.0
# 3  3.0  4.0
# ...

# %%
testdata.loc[testdata['Fare']<=10, 'F']=1
testdata.loc[(testdata['Fare']>10) & (testdata['Fare']<=30), 'F']=2
testdata.loc[(testdata['Fare']>30) & (testdata['Fare']<=50), 'F']=3
testdata.loc[(testdata['Fare']>50) & (testdata['Fare']<=70), 'F']=4
testdata.loc[(testdata['Fare']>70) & (testdata['Fare']<=100), 'F']=4
testdata.loc[testdata['Fare']>100, 'F']=5
testdata.head(5)
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch     Fare Cabin Embarked  Place  Family  Gender    A    F
# 0      0   7.8292   NaN        Q      3       0       2  3.0  1.0
# 1      0   7.0000   NaN        S      1       1       1  3.0  1.0
# 2      0   9.6875   NaN        Q      3       0       2  4.0  1.0
# 3      0   8.6625   NaN        S      1       0       2  2.0  1.0
# 4      1  12.2875   NaN        S      1       2       1  2.0  2.0

# %%
traindata['PGA']= traindata['Pclass']*traindata['Gender']*traindata['A']
testdata['PGA']=testdata['Pclass']*testdata['Gender']*traindata['A']
traindata.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Place  Family  Gender  \
# 0    male  22.0      1      0   7.2500   NaN        S      1       1       2
# 1  female  38.0      1      0  71.2833   C85        C      2       1       1
# 2  female  26.0      0      0   7.9250   NaN        S      1       0       1
# 3  female  35.0      1      0  53.1000  C123        S      1       1       1
# 4    male  35.0      0      0   8.0500   NaN        S      1       0       2
#
#      A    F   PGA
# 0  2.0  1.0  12.0
# 1  3.0  4.0   3.0
# ...

# %%
for name in traindata["Name"]:
    traindata["Title"] = traindata["Name"].str.extract("([A-Za-z]+)\.",expand=False)
    
for name in testdata["Name"]:
    testdata["Title"] = testdata["Name"].str.extract("([A-Za-z]+)\.",expand=False)
traindata.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Place  Family  Gender  \
# 0    male  22.0      1      0   7.2500   NaN        S      1       1       2
# 1  female  38.0      1      0  71.2833   C85        C      2       1       1
# 2  female  26.0      0      0   7.9250   NaN        S      1       0       1
# 3  female  35.0      1      0  53.1000  C123        S      1       1       1
# 4    male  35.0      0      0   8.0500   NaN        S      1       0       2
#
#      A    F   PGA Title
# 0  2.0  1.0  12.0    Mr
# 1  3.0  4.0   3.0   Mrs
# ...

# %%
testdata.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch     Fare Cabin Embarked  Place  Family  Gender    A    F   PGA Title
# 0      0   7.8292   NaN        Q      3       0       2  3.0  1.0  12.0    Mr
# 1      0   7.0000   NaN        S      1       1       1  3.0  1.0   9.0   Mrs
# 2      0   9.6875   NaN        Q      3       0       2  4.0  1.0   8.0    Mr
# 3      0   8.6625   NaN        S      1       0       2  2.0  1.0  18.0    Mr
# 4      1  12.2875   NaN        S      1       2       1  2.0  2.0   9.0   Mrs

# %%
rep = {"Don": "Other", "Rev": "Other", "Dr": "Other", "Major": "Other", "Lady": "Other", "Sir": "Other", "Mlle": "Other", "Col": "Other", "Capt": "Other", "Countess": "Other", "Jonkheer": "Other", "Mme": "Other", "Ms": "Other", "Dona": "Other"}

traindata.replace({"Title": rep}, inplace=True)

traindata.loc[traindata["Title"] == "Miss", "Title"] = 0
traindata.loc[traindata["Title"] == "Mr", "Title"] = 1
traindata.loc[traindata["Title"] == "Mrs", "Title"] = 2
traindata.loc[traindata["Title"] == "Master", "Title"] = 3
traindata.loc[traindata["Title"] == "Other", "Title"] = 4

# %%
traindata.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Place  Family  Gender  \
# 0    male  22.0      1      0   7.2500   NaN        S      1       1       2
# 1  female  38.0      1      0  71.2833   C85        C      2       1       1
# 2  female  26.0      0      0   7.9250   NaN        S      1       0       1
# 3  female  35.0      1      0  53.1000  C123        S      1       1       1
# 4    male  35.0      0      0   8.0500   NaN        S      1       0       2
#
#      A    F   PGA  Title
# 0  2.0  1.0  12.0      1
# ...

# %%
testdata.replace({"Title": rep}, inplace=True)

# %%
testdata.loc[testdata["Title"] == "Miss", "Title"] = 0
testdata.loc[testdata["Title"] == "Mr", "Title"] = 1
testdata.loc[testdata["Title"] == "Mrs", "Title"] = 2
testdata.loc[testdata["Title"] == "Master", "Title"] = 3
testdata.loc[testdata["Title"] == "Other", "Title"] = 4

# %%
testdata.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch     Fare Cabin Embarked  Place  Family  Gender    A    F   PGA  Title
# 0      0   7.8292   NaN        Q      3       0       2  3.0  1.0  12.0      1
# 1      0   7.0000   NaN        S      1       1       1  3.0  1.0   9.0      2
# 2      0   9.6875   NaN        Q      3       0       2  4.0  1.0   8.0      1
# 3      0   8.6625   NaN        S      1       0       2  2.0  1.0  18.0      1
# 4      1  12.2875   NaN        S      1       2       1  2.0  2.0   9.0      2

# %%
sb.pairplot(traindata)

# %%
from sklearn.metrics import make_scorer, accuracy_score

# %%
features=['Pclass', 'Place', 'Family', 'Gender', 'PGA', 'F', 'A', 'Title']
xtrain= traindata[features]
ytrain= traindata['Survived']
xtest= testdata[features]

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(xtrain, ytrain, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
pred_dt = dt_clf.predict(X_valid)
acc_dt = accuracy_score(y_valid, pred_dt)

print(acc_dt)
# Out:
# 0.8268156424581006

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_valid)
acc_rf = accuracy_score(y_valid, pred_rf)

print(acc_rf)
# Out:
# 0.8491620111731844

# %%
from sklearn.svm import SVC, LinearSVC
svc_clf = SVC() 
svc_clf.fit(X_train, y_train)
pred_svc = svc_clf.predict(X_valid)
acc_svc = accuracy_score(y_valid, pred_svc)

print(acc_svc)
# Out:
# 0.8268156424581006

# %%
Y_pred = rf_clf.predict(xtest)

# %%
testdata['Survived']=Y_pred

# %%
testdata.head(10)
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5       3                    Svensson, Mr. Johan Cervin    male  14.0      0
# 6       3                          Connolly, Miss. Kate  female  30.0      0
# 7       2                  Caldwell, Mr. Albert Francis    male  26.0      1
# 8       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9       3                       Davies, Mr. John Samuel    male  21.0      2
#
#    Parch     Fare Cabin Embarked  Place  Family  Gender    A    F   PGA  \
# ...
